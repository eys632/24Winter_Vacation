# %%
# !pip install -qU langchain_community
# !pip install -qU unstructured
# Out:
# WARNING: Skipping C:\Users\eys63\anaconda3\Lib\site-packages\tensorflow_intel-2.18.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\eys63\anaconda3\Lib\site-packages\tensorflow_intel-2.18.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\eys63\anaconda3\Lib\site-packages\tensorflow_intel-2.18.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\eys63\anaconda3\Lib\site-packages\tensorflow_intel-2.18.0.dist-info due to invalid metadata entry 'name'

# %%
from langchain_community.document_loaders import DirectoryLoader

#디렉토리 초기화
loader = DirectoryLoader("../", glob="*.*")
#문서로드
docs = loader.load()
#문서 개수 계싼
len(docs)
# Out:
# libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
# Error loading file ..\SECURITY.md
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[10], line 6
#       4 loader = DirectoryLoader("../", glob="*.*")
#       5 #문서로드
# ----> 6 docs = loader.load()
#       7 #문서 개수 계싼
#       8 len(docs)
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\langchain_community\document_loaders\directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\langchain_community\document_loaders\directory.py:195, in DirectoryLoader.lazy_load(self)
#     193 else:
#     194     for i in items:
# --> 195         yield from self._lazy_load_file(i, p, pbar)
#     197 if pbar:
#     198     pbar.close()
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\langchain_community\document_loaders\directory.py:233, in DirectoryLoader._lazy_load_file(self, item, path, pbar)
#     231     else:
#     232         logger.error(f"Error loading file {str(item)}")
# --> 233         raise e
#     234 finally:
#     235     if pbar:
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\langchain_community\document_loaders\directory.py:223, in DirectoryLoader._lazy_load_file(self, item, path, pbar)
#     221 loader = self.loader_cls(str(item), **self.loader_kwargs)
#     222 try:
# --> 223     for subdoc in loader.lazy_load():
#     224         yield subdoc
#     225 except NotImplementedError:
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\langchain_community\document_loaders\unstructured.py:107, in UnstructuredBaseLoader.lazy_load(self)
#     105 def lazy_load(self) -> Iterator[Document]:
#     106     """Load file."""
# --> 107     elements = self._get_elements()
#     108     self._post_process_elements(elements)
#     109     if self.mode == "elements":
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\langchain_community\document_loaders\unstructured.py:228, in UnstructuredFileLoader._get_elements(self)
#     226 if isinstance(self.file_path, Path):
#     227     self.file_path = str(self.file_path)
# --> 228 return partition(filename=self.file_path, **self.unstructured_kwargs)
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\partition\auto.py:279, in partition(filename, file, encoding, content_type, url, headers, ssl_verify, request_timeout, strategy, skip_infer_table_types, ocr_languages, languages, detect_language_per_element, pdf_infer_table_structure, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, data_source_metadata, metadata_filename, hi_res_model_name, model_name, starting_page_number, **kwargs)
#     276 partitioning_kwargs["strategy"] = strategy
#     278 partition = partitioner_loader.get(file_type)
# --> 279 elements = partition(filename=filename, file=file, **partitioning_kwargs)
#     280 return augment_metadata(elements)
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\partition\md.py:78, in partition_md(filename, file, text, url, metadata_filename, metadata_last_modified, **kwargs)
#      74     text = response.text
#      76 html = markdown.markdown(text, extensions=["tables"])
# ---> 78 return partition_html(
#      79     text=html,
#      80     metadata_filename=metadata_filename or filename,
#      81     metadata_file_type=FileType.MD,
#      82     metadata_last_modified=metadata_last_modified or last_modified,
#      83     detection_origin=DETECTION_ORIGIN,
#      84     **kwargs,
#      85 )
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\partition\common\metadata.py:162, in apply_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     160 @functools.wraps(func)
#     161 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> list[Element]:
# --> 162     elements = func(*args, **kwargs)
#     163     call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#     165     # ------------------------------------------------------------------------------------
#     166     # unique-ify elements
#     167     # ------------------------------------------------------------------------------------
#    (...)
#     172     # instance).
#     173     # ------------------------------------------------------------------------------------
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\chunking\dispatch.py:74, in add_chunking_strategy.<locals>.wrapper(*args, **kwargs)
#      71 """The decorated function is replaced with this one."""
#      73 # -- call the partitioning function to get the elements --
# ---> 74 elements = func(*args, **kwargs)
#      76 # -- look for a chunking-strategy argument --
#      77 call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\partition\html\partition.py:91, in partition_html(filename, file, text, encoding, url, headers, ssl_verify, skip_headers_and_footers, detection_origin, html_parser_version, image_alt_mode, **kwargs)
#      75     return []
#      77 opts = HtmlPartitionerOptions(
#      78     file_path=filename,
#      79     file=file,
#    (...)
#      88     image_alt_mode=image_alt_mode,
#      89 )
# ---> 91 return list(_HtmlPartitioner.iter_elements(opts))
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\partition\html\partition.py:189, in _HtmlPartitioner.iter_elements(cls, opts)
#     186 @classmethod
#     187 def iter_elements(cls, opts: HtmlPartitionerOptions) -> Iterator[Element]:
#     188     """Partition HTML document provided by `opts` into document-elements."""
# --> 189     yield from cls(opts)._iter_elements()
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\partition\html\partition.py:202, in _HtmlPartitioner._iter_elements(self)
#     192 """Generated document-elements (e.g. Title, NarrativeText, etc.) parsed from document.
#     193
#     194 Elements appear in document order.
#     195 """
#     196 elements_iter = (
#     197     self._main.iter_elements()
#     198     if self._opts.html_parser_version == "v1"
#     199     else self._from_ontology
#     200 )
# --> 202 for e in elements_iter:
#     203     e.metadata.last_modified = self._opts.last_modified
#     204     e.metadata.detection_origin = self._opts.detection_origin
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\partition\html\parser.py:359, in Flow.iter_elements(self)
#     357 assert not q[0].is_phrasing
#     358 block_item = cast(Flow, q.popleft())
# --> 359 yield from block_item.iter_elements()
#     360 yield from self._element_from_text_or_tail(block_item.tail or "", q)
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\partition\html\parser.py:354, in Flow.iter_elements(self)
#     351 # -- place child elements in a queue --
#     352 q: deque[Flow | Phrasing] = deque(self)
# --> 354 yield from self._element_from_text_or_tail(self.text or "", q, self._ElementCls)
#     356 while q:
#     357     assert not q[0].is_phrasing
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\partition\html\parser.py:384, in Flow._element_from_text_or_tail(self, text, q, ElementCls)
#     381         yield from element_accum.flush(ElementCls)
#     382         yield node
# --> 384 yield from element_accum.flush(ElementCls)
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\partition\html\parser.py:252, in _ElementAccumulator.flush(self, ElementCls)
#     250 # -- if we don't have a more specific element-class, choose one based on the text --
#     251 if ElementCls is None:
# --> 252     ElementCls = derive_element_type_from_text(normalized_text)
#     253     # -- normalized text that contains only a single character is skipped unless it
#     254     # -- identifies as a list-item
#     255     if ElementCls is None:
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\partition\html\parser.py:884, in derive_element_type_from_text(text)
#     881 if len(text) < 2:
#     882     return None
# --> 884 if is_possible_narrative_text(text):
#     885     return NarrativeText
#     887 return Text
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\partition\text_type.py:74, in is_possible_narrative_text(text, cap_threshold, non_alpha_threshold, languages, language_checks)
#      69 # NOTE(robinson): it gets read in from the environment as a string so we need to
#      70 # cast it to a float
#      71 cap_threshold = float(
#      72     os.environ.get("UNSTRUCTURED_NARRATIVE_TEXT_CAP_THRESHOLD", cap_threshold),
#      73 )
# ---> 74 if exceeds_cap_ratio(text, threshold=cap_threshold):
#      75     trace_logger.detail(f"Not narrative. Text exceeds cap ratio {cap_threshold}:\n\n{text}")  # type: ignore # noqa: E501
#      76     return False
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\partition\text_type.py:270, in exceeds_cap_ratio(text, threshold)
#     257 """Checks the title ratio in a section of text. If a sufficient proportion of the words
#     258 are capitalized, that can be indicated on non-narrative text (i.e. "1A. Risk Factors").
#     259
#    (...)
#     266     the function returns True
#     267 """
#     268 # NOTE(robinson) - Currently limiting this to only sections of text with one sentence.
#     269 # The assumption is that sections with multiple sentences are not titles.
# --> 270 if sentence_count(text, 3) > 1:
#     271     return False
#     273 if text.isupper():
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\partition\text_type.py:219, in sentence_count(text, min_length)
#     208 def sentence_count(text: str, min_length: Optional[int] = None) -> int:
#     209     """Checks the sentence count for a section of text. Titles should not be more than one
#     210     sentence.
#     211
#    (...)
#     217         The min number of words a section needs to be for it to be considered a sentence.
#     218     """
# --> 219     sentences = sent_tokenize(text)
#     220     count = 0
#     221     for sentence in sentences:
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\unstructured\nlp\tokenize.py:57, in sent_tokenize(text)
#      55 """A wrapper around the NLTK sentence tokenizer with LRU caching enabled."""
#      56 _download_nltk_packages_if_not_present()
# ---> 57 return _sent_tokenize(text)
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\nltk\tokenize\__init__.py:106, in sent_tokenize(text, language)
#      96 def sent_tokenize(text, language="english"):
#      97     """
#      98     Return a sentence-tokenized copy of *text*,
#      99     using NLTK's recommended sentence tokenizer
#    (...)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\nltk\data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     747     print(f"<<Loading {resource_url}>>")
#     749 # Load the resource.
# --> 750 opened_resource = _open(resource_url)
#     752 if format == "raw":
#     753     resource_val = opened_resource.read()
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\nltk\data.py:876, in _open(resource_url)
#     873 protocol, path_ = split_resource_url(resource_url)
#     875 if protocol is None or protocol.lower() == "nltk":
# --> 876     return find(path_, path + [""]).open()
#     877 elif protocol.lower() == "file":
#     878     # urllib might not use mode='rb', so handle this one ourselves:
#     879     return find(path_, [""]).open()
#
# File c:\Users\eys63\anaconda3\Lib\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/english.pickle
#
#   Searched in:
#     - 'C:\\Users\\eys63/nltk_data'
#     - 'c:\\Users\\eys63\\anaconda3\\nltk_data'
#     - 'c:\\Users\\eys63\\anaconda3\\share\\nltk_data'
#     - 'c:\\Users\\eys63\\anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\eys63\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - ''
# **********************************************************************
